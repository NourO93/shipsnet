# %% [markdown]
# # Bring in imports

# %%
import random
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches


import json  
import mpl_toolkits
import os
import pickle
import glob
import re
import itertools
import time

import cv2
import argparse as ap


import sklearn as sklearn
from sklearn.metrics import confusion_matrix
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn import model_selection
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier as MLPC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.externals import joblib
from sklearn import model_selection
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import roc_curve, auc
from keras.utils import np_utils

import tensorflow as tf
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras import initializers, layers, models
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras import callbacks
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils
from keras.optimizers import SGD


import pyimagesearch.imutils as imutils
from pyimagesearch.helpers import pyramid
from pyimagesearch.helpers import sliding_window
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load data

# %%
image_data = pickle.load(open("image_data.pkl", "rb"))

# %%
image_tag = pickle.load(open("image_tag.pkl","rb"))

# %%
scene1 = mpimg.imread('scenes/lb_1.png')
scene2 = mpimg.imread('scenes/lb_2.png')
scene3 = mpimg.imread('scenes/lb_3.png')
scene4 = mpimg.imread('scenes/lb_4.png')
scene5 = mpimg.imread('scenes/sfbay_1.png')
scene6 = mpimg.imread('scenes/sfbay_2.png')
scene7 = mpimg.imread('scenes/sfbay_3.png')
scene8 = mpimg.imread('scenes/sfbay_4.png')

# %%
# ext = re.compile('.*.png')
# i = 1
# for image in os.listdir('scenes'):
#     if ext.match(image):
#         globals()['string%s' % 1] = cv2.imread('scenes/'+name)
#         print(type(string1))
#         print(image)
#         i+=1

# %% [markdown]
# # Bring in helpers

# %%
def scan_image(model,image,stepSize,proba):
    (winW, winH) = (80, 80)
    output = []
    cnn_windows = []
    cnn_coords = []
    i = 0
    for (x, y, window) in sliding_window(image, stepSize=stepSize, windowSize=(winW, winH)):
        if window.shape[0] != winH or window.shape[1] != winW:
            continue
        cnn_window = np.expand_dims(window, axis=0)
        y_pred = model.predict(cnn_window)
        y_pred_val = list(y_pred[0])[1]
        
        if y_pred_val > proba :
            cnn_coords.append((x,y))
            cnn_windows.append(window)
        i+=1
    output.append(cnn_windows)
    output.append(cnn_coords)
    return output

# %%
def plot_found(cnn_coords,image):
    fig,ax = plt.subplots(1)
    ax.imshow(image)

    for i in cnn_coords:
        rect = patches.Rectangle(i,80,80,linewidth=4,edgecolor='r',facecolor='none')
        ax.add_patch(rect)
    plt.show()

# %%
# from pylab import rcParams
# rcParams['figure.figsize'] = 30, 30

# i = 1
# for image in scenes:
#     plt.subplot(4,2,i)
#     plt.imshow(globals()[image])
#     i+=1

# %%
def plot_learning(model_history):
    plt.plot(model_history.history['acc'])
    plt.plot(model_history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

def plot_loss(model_history):
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# # Make test and train

# %%
X = np.asarray(image_data)
y = np.asarray(image_tag)

# %%
X = X/ 255

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1234, stratify = y, shuffle = True)

# %%
# output encoding
y_train = np_utils.to_categorical(y_train, 2)
y_test = np_utils.to_categorical(y_test, 2)

# %%
np.random.seed(42)

# %%
y_test[1]
# Out:
# array([0., 1.], dtype=float32)

# %% [markdown]
# ## Make a rotated X_train and y_train

# %%
datagen = ImageDataGenerator(
        rotation_range=90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True
)  # randomly flip images

datagen.fit(X_train)

# %%
len(X_train)/2
# Out:
# 1120.0

# %%
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=1120, shuffle = True):
    # Show 9 images
#     for i in range(0, 9):
#         plt.subplot(330 + 1 + i)
#         plt.imshow(X_batch[i])
#         plt.title(y_batch[i])
#     # show the plot
#     plt.show()
    break

# %%
X_rot = np.concatenate((X_train,X_batch))
y_rot = np.concatenate((y_train,y_batch))

# %%
def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %%
X_rot_shuf, y_rot_shuf = unison_shuffled_copies(X_rot,y_rot)

# %% [markdown]
# # Run models

# %% [markdown]
# ## byrachonok model

# %%
# network design
B1 = Sequential()

B1.add(Conv2D(32, (3, 3), padding='same', input_shape=(80, 80, 3), activation='relu'))
B1.add(MaxPooling2D(pool_size=(2, 2))) #40x40
B1.add(Dropout(0.25))

B1.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
B1.add(MaxPooling2D(pool_size=(2, 2))) #20x20
B1.add(Dropout(0.25))

B1.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
B1.add(MaxPooling2D(pool_size=(2, 2))) #10x10
B1.add(Dropout(0.25))

B1.add(Conv2D(32, (10, 10), padding='same', activation='relu'))
B1.add(MaxPooling2D(pool_size=(2, 2))) #5x5
B1.add(Dropout(0.25))

B1.add(Flatten())
B1.add(Dense(512, activation='relu'))
B1.add(Dropout(0.5))

B1.add(Dense(2, activation='softmax'))

# %%
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
B1.compile(
    loss='categorical_crossentropy',
    optimizer=sgd,
    metrics=['accuracy'])

# training
B1_history = B1.fit(
    X_train, 
    y_train,
    batch_size=32,
    epochs=20,
    validation_split=0.2,
    shuffle=True,
    verbose=2)
# Out:
# Train on 1792 samples, validate on 448 samples
# Epoch 1/20
#  - 2s - loss: 0.5094 - acc: 0.7729 - val_loss: 0.3357 - val_acc: 0.8839
# Epoch 2/20
#  - 1s - loss: 0.2885 - acc: 0.8834 - val_loss: 0.2988 - val_acc: 0.8594
# Epoch 3/20
#  - 1s - loss: 0.2443 - acc: 0.8996 - val_loss: 0.1885 - val_acc: 0.9263
# Epoch 4/20
#  - 1s - loss: 0.2108 - acc: 0.9174 - val_loss: 0.2803 - val_acc: 0.9040
# Epoch 5/20
#  - 1s - loss: 0.1915 - acc: 0.9185 - val_loss: 0.1554 - val_acc: 0.9375
# Epoch 6/20
#  - 1s - loss: 0.1654 - acc: 0.9330 - val_loss: 0.1276 - val_acc: 0.9531
# Epoch 7/20
#  - 1s - loss: 0.1674 - acc: 0.9336 - val_loss: 0.1072 - val_acc: 0.9598
# Epoch 8/20
#  - 1s - loss: 0.1299 - acc: 0.9475 - val_loss: 0.1274 - val_acc: 0.9643
# Epoch 9/20
#  - 1s - loss: 0.1241 - acc: 0.9498 - val_loss: 0.1231 - val_acc: 0.9621
# Epoch 10/20
#  - 1s - loss: 0.1156 - acc: 0.9559 - val_loss: 0.0839 - val_acc: 0.9777
# Epoch 11/20
#  - 1s - loss: 0.1358 - acc: 0.9542 - val_loss: 0.1180 - val_acc: 0.9554
# Epoch 12/20
#  - 1s - loss: 0.1126 - acc: 0.9559 - val_loss: 0.0899 - val_acc: 0.9621
# Epoch 13/20
#  - 1s - loss: 0.0997 - acc: 0.9671 - val_loss: 0.0792 - val_acc: 0.9732
# Epoch 14/20
#  - 1s - loss: 0.0999 - acc: 0.9660 - val_loss: 0.1084 - val_acc: 0.9732
# Epoch 15/20
#  - 1s - loss: 0.0901 - acc: 0.9693 - val_loss: 0.0974 - val_acc: 0.9688
# Epoch 16/20
#  - 1s - loss: 0.0874 - acc: 0.9704 - val_loss: 0.1017 - val_acc: 0.9732
# Epoch 17/20
#  - 1s - loss: 0.0719 - acc: 0.9760 - val_loss: 0.0969 - val_acc: 0.9732
# Epoch 18/20
#  - 1s - loss: 0.0763 - acc: 0.9727 - val_loss: 0.1285 - val_acc: 0.9621
# Epoch 19/20
#  - 1s - loss: 0.0694 - acc: 0.9782 - val_loss: 0.1191 - val_acc: 0.9643
# Epoch 20/20
#  - 1s - loss: 0.0907 - acc: 0.9682 - val_loss: 0.0950 - val_acc: 0.9754

# %%
plot_learning(B1_history)
plot_loss(B1_history)

# %%
B1.evaluate(X_test, y_test, verbose=1)
# Out:
# 560/560 [==============================] - 0s 291us/step
# [0.09691183497863157, 0.9678571428571429]

# %%
B1.save('final_model.h5')

# %% [markdown]
# ## test on web image

# %%
from PIL import Image
testsc = Image.open('planet-sc.png')
if testsc.mode == 'RGBA':
    testsc = testsc.convert('RGB')
    h = testsc.size[0]
    w = testsc.size[1]
    testsc = testsc.resize((3*h,3*w))
    testsc = np.asarray(testsc)

# %%
plt.imshow(testsc)

# %%
output = scan_image(B1,testsc,12,.4)

# %%
plot_found(output[1],testsc)

# %% [markdown]
# ## Cambridge Spark Model

# %%
C1 = Sequential()

C1.add(Conv2D(32, (3, 3), input_shape=(80, 80, 3), activation='relu'))
C1.add(MaxPooling2D(pool_size=(2, 2)))
C1.add(Dropout(0.25))

C1.add(Conv2D(32, (3, 3), input_shape=(80, 80, 3), activation='relu'))
C1.add(MaxPooling2D(pool_size=(2, 2)))
C1.add(Dropout(0.25))

C1.add(Flatten())
C1.add(Dense(128, activation='relu'))
C1.add(Dropout(0.5))

C1.add(Dense(2, activation='softmax'))

# %%
C1.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# training
C1_history = C1.fit(
    X_train, 
    y_train,
    batch_size=32,
    epochs=18,
    validation_split=0.2,
    shuffle=True,
    verbose=2)

C1.evaluate(X_test, y_test, verbose=1)
# Out:
# Train on 1792 samples, validate on 448 samples
# Epoch 1/18
#  - 3s - loss: 0.4989 - acc: 0.7729 - val_loss: 0.3724 - val_acc: 0.8862
# Epoch 2/18
#  - 1s - loss: 0.2917 - acc: 0.8783 - val_loss: 0.3882 - val_acc: 0.8571
# Epoch 3/18
#  - 1s - loss: 0.2606 - acc: 0.8962 - val_loss: 0.1956 - val_acc: 0.9174
# Epoch 4/18
#  - 1s - loss: 0.2097 - acc: 0.9096 - val_loss: 0.2375 - val_acc: 0.9174
# Epoch 5/18
#  - 1s - loss: 0.1830 - acc: 0.9263 - val_loss: 0.1523 - val_acc: 0.9397
# Epoch 6/18
#  - 1s - loss: 0.1720 - acc: 0.9291 - val_loss: 0.1613 - val_acc: 0.9308
# Epoch 7/18
#  - 1s - loss: 0.1753 - acc: 0.9263 - val_loss: 0.1309 - val_acc: 0.9509
# Epoch 8/18
#  - 1s - loss: 0.1384 - acc: 0.9453 - val_loss: 0.1291 - val_acc: 0.9487
# Epoch 9/18
#  - 1s - loss: 0.1399 - acc: 0.9459 - val_loss: 0.1515 - val_acc: 0.9375
# Epoch 10/18
#  - 1s - loss: 0.1368 - acc: 0.9537 - val_loss: 0.1048 - val_acc: 0.9598
# Epoch 11/18
#  - 1s - loss: 0.1285 - acc: 0.9487 - val_loss: 0.0990 - val_acc: 0.9554
# Epoch 12/18
#  - 1s - loss: 0.1161 - acc: 0.9554 - val_loss: 0.0908 - val_acc: 0.9598
# Epoch 13/18
#  - 1s - loss: 0.1008 - acc: 0.9693 - val_loss: 0.1521 - val_acc: 0.9263
# Epoch 14/18
#  - 1s - loss: 0.1236 - acc: 0.9581 - val_loss: 0.0918 - val_acc: 0.9598
# Epoch 15/18
#  - 1s - loss: 0.1006 - acc: 0.9637 - val_loss: 0.0835 - val_acc: 0.9643
# Epoch 16/18
#  - 1s - loss: 0.0996 - acc: 0.9626 - val_loss: 0.0866 - val_acc: 0.9643
# Epoch 17/18
#  - 1s - loss: 0.0787 - acc: 0.9727 - val_loss: 0.0911 - val_acc: 0.9531
# Epoch 18/18
#  - 1s - loss: 0.0752 - acc: 0.9738 - val_loss: 0.0691 - val_acc: 0.9665
# 560/560 [==============================] - 0s 207us/step
# [0.07419033928641251, 0.9732142857142857]

# %%
plot_learning(C1_history)
plot_loss(C1_history)

# %%
C1_output = scan_image(C1,scene1,12,.9)
plot_found(C1_output[1],scene1)

# %% [markdown]
# ### With rotation

# %%
C1.fit_generator(datagen.flow(X_train, y_train, batch_size=32), 
                 shuffle=True, 
                 epochs=18,
                 validation_split=0.2,
                 shuffle=True,
                 verbose=1)

C1.evaluate(X_test, y_test, verbose=1)

# %% [markdown]
# ## Paul M Model

# %%
P1 = Sequential()

P1.add(Conv2D(32, (3, 3), input_shape=(80, 80, 3), activation='relu'))
P1.add(Conv2D(64, (3, 3), activation='relu'))
P1.add(MaxPooling2D(pool_size=(2, 2))) #40x40
P1.add(Dropout(0.25))
P1.add(Flatten())

P1.add(Dense(128, activation='relu'))
P1.add(Dropout(0.5))
P1.add(Dense(2, activation='softmax'))

# %%
P1.compile(
    loss='categorical_crossentropy',
    optimizer=keras.optimizers.Adadelta(),
    metrics=['accuracy'])

# training
P1_history = P1.fit(
    X_train, 
    y_train,
    batch_size=32,
    epochs=18,
    validation_split=0.2,
    shuffle=True,
    verbose=2)

P1.evaluate(X_test, y_test, verbose=1)
# Out:
# Train on 1792 samples, validate on 448 samples
# Epoch 1/18
#  - 4s - loss: 0.5375 - acc: 0.8265 - val_loss: 0.2369 - val_acc: 0.9219
# Epoch 2/18
#  - 3s - loss: 0.2868 - acc: 0.8912 - val_loss: 0.2208 - val_acc: 0.9085
# Epoch 3/18
#  - 3s - loss: 0.2081 - acc: 0.9163 - val_loss: 0.1654 - val_acc: 0.9397
# Epoch 4/18
#  - 3s - loss: 0.2013 - acc: 0.9291 - val_loss: 0.1366 - val_acc: 0.9487
# Epoch 5/18
#  - 3s - loss: 0.1807 - acc: 0.9302 - val_loss: 0.1715 - val_acc: 0.9330
# Epoch 6/18
#  - 3s - loss: 0.1278 - acc: 0.9515 - val_loss: 0.1098 - val_acc: 0.9598
# Epoch 7/18
#  - 3s - loss: 0.1169 - acc: 0.9570 - val_loss: 0.1066 - val_acc: 0.9576
# Epoch 8/18
#  - 3s - loss: 0.1088 - acc: 0.9604 - val_loss: 0.1200 - val_acc: 0.9464
# Epoch 9/18
#  - 3s - loss: 0.0883 - acc: 0.9643 - val_loss: 0.1031 - val_acc: 0.9554
# Epoch 10/18
#  - 3s - loss: 0.0897 - acc: 0.9671 - val_loss: 0.0975 - val_acc: 0.9598
# Epoch 11/18
#  - 3s - loss: 0.0733 - acc: 0.9782 - val_loss: 0.0951 - val_acc: 0.9710
# Epoch 12/18
#  - 3s - loss: 0.0554 - acc: 0.9782 - val_loss: 0.1186 - val_acc: 0.9576
# Epoch 13/18
#  - 3s - loss: 0.0544 - acc: 0.9838 - val_loss: 0.0763 - val_acc: 0.9710
# Epoch 14/18
#  - 3s - loss: 0.0463 - acc: 0.9855 - val_loss: 0.0958 - val_acc: 0.9598
# Epoch 15/18
#  - 3s - loss: 0.0476 - acc: 0.9866 - val_loss: 0.0891 - val_acc: 0.9732
# Epoch 16/18
#  - 3s - loss: 0.0350 - acc: 0.9877 - val_loss: 0.0810 - val_acc: 0.9688
# Epoch 17/18
#  - 3s - loss: 0.0338 - acc: 0.9900 - val_loss: 0.1060 - val_acc: 0.9665
# Epoch 18/18
#  - 3s - loss: 0.0213 - acc: 0.9944 - val_loss: 0.0905 - val_acc: 0.9688
# 560/560 [==============================] - 0s 417us/step
# [0.11397504072104181, 0.9660714285714286]

# %%
plot_learning(P1_history)
plot_loss(P1_history)

# %%
P1_output = scan_image(P1,scene2,12,.9)
plot_found(P1_output[1],scene2)
